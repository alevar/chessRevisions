# %%
import os
import sys
import pandas as pd
import numpy as np
from shutil import copyfile

version="2.04"
gff3Cols=["seqid","source","type","start","end","score","strand","phase","attributes"]

# %%
# this notebook is dedicated to parsing the chess2.02.gff files, and introducing several improvements/corrections
# the corrections include:
# 1. Extension of the transcript start based on a suspected trimmed ORF (as inferred from the known isoforms)
# 2. Extension of the transctipt end based on a suspected trimming og the ORF (inferred from the known isoforms)
# 3.

# %%
# first need to load the frame
df=pd.read_csv("./revision/mergedExonDF.csv")
df.drop("Unnamed: 0",axis=1,inplace=True)

# case 99999 should never exist for novel however, since all novel should have a corresponding known transcript
# assert len(df[df["match"]>2])==0, 'something is wrong witth the known and novel transcripts. Some novel transcript does not have a known pair'
df=df[df["match"].isin([0,1,2])].reset_index(drop=True)
# let's isolate suspicious cases such as 777777
setStartTrimShort=set(df[df["startTrim"]==7777777]["parent"])
setEndTrimShort=set(df[df["nonesenseTrim"]==7777777]["parent"])
assert setStartTrimShort==setEndTrimShort, "something is wrong with the ORF fitting inside the novel transcript"

print("number of transcripts with extremely short or non-fitting ORFs is: ",len(setStartTrimShort))
print("total number of transcripts considered: ",len(df))
# Out:
# number of transcripts with extremely short or non-fitting ORFs is:  0
# total number of transcripts considered:  94337

# %%
# now we need to work with the rest of the transcripts and correct their annotation in the CHESS.gff

# first let's isolate those transcripts for which the start is missing:
startDF=df[(df["startTrim"]<=100)&(df["startTrim"]>0)&(df["numExonsStart"]==0)].reset_index(drop=True)
endDF=df[(df["nonesenseTrim"]<=100)&(df["nonesenseTrim"]>0)&(df["numExonsEnd"]==0)].reset_index(drop=True)
print('numnber of transcripts with trimmed start AND end is ',len(set(startDF['parent']).intersection(set(endDF['parent']))))
print('total number of transcripts that require adjustment',len(set(startDF['parent']).union(set(endDF['parent']))))
# now need to build dictionaries linking each parent to the number of bases trimmed of either start OR end (separate dataframes)
startDict=pd.Series(startDF.startTrim.values,index=startDF.parent).to_dict()
endDict=pd.Series(endDF.nonesenseTrim.values,index=endDF.parent).to_dict()
setStarts=set(startDict) # to be used for quick lookup when traversing the GFF
setEnds=set(endDict) # to be used for quick lookup when traversing the GFF
# Out:
# numnber of transcripts with trimmed start AND end is  38
# total number of transcripts that require adjustment 2971

# %%
len(startDF[startDF["startTrim"]<5])
# Out:
# 278

# %%
outFP=open("./chess2.04.gff","w+")
tmpLine=None
with open("./chess2.03.gff","r") as fp:
    ifp=iter(fp)
    while True:
        try:
            line=""
            if tmpLine==None:
                line=next(ifp)
            else:
                line=tmpLine
                tmpLine=None
                
            if line[0]=="#":
                if line[:7]=="##CHESS":
                    outFP.write("##CHESS"+version+"\n")
                else:
                    outFP.write(line)
                continue
            else:
                lineCols=line.split("\t")
                if lineCols[2]=="transcript":
                    chsID=lineCols[8].split("ID=")[-1].split(";")[0].strip()
                    if chsID in setStarts:
                        # now we shall collect all the necessary parts (exons) for the given novel transcript
                        if lineCols[6]=="+":
                            # change right-most coordinate of the transcript
                            transStart=lineCols[3]
                            lineCols[3]=str(int(transStart)-startDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"+ wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setStarts and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[3]==transStart:
                                        lineCols[3]=str(int(lineCols[3])-startDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                        else:
                            # change left-most coordinate of the transcript
                            transEnd=lineCols[4]
                            lineCols[4]=str(int(transEnd)+startDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setStarts and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[4]==transEnd:
                                        lineCols[4]=str(int(lineCols[4])+startDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                                        
                    elif chsID in setEnds:
                        # now we shall collect all the necessary parts (exons) for the given novel transcript
                        if lineCols[6]=="+":
                            # change right-most coordinate of the transcript
                            transEnd=lineCols[4]
                            lineCols[4]=str(int(transEnd)+endDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"+ wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setEnds and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[4]==transEnd:
                                        lineCols[4]=str(int(lineCols[4])-endDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                        else:
                            # change left-most coordinate of the transcript
                            transStart=lineCols[3]
                            lineCols[3]=str(int(transStart)+endDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setEnds and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[3]==transStart:
                                        lineCols[3]=str(int(lineCols[3])+endDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                    else:
                        outFP.write(line)
                else:
                    outFP.write(line)
        except StopIteration:
            break
            
outFP.close()

# %%
# now to do the same with the chess2.02_assembly.gff version

outFP=open("./chess2.04_assembly.gff","w+")
tmpLine=None
with open("./chess2.03_assembly.gff","r") as fp:
    ifp=iter(fp)
    while True:
        try:
            line=""
            if tmpLine==None:
                line=next(ifp)
            else:
                line=tmpLine
                tmpLine=None
                
            if line[0]=="#":
                if line[:7]=="##CHESS":
                    outFP.write("##CHESS"+version+"\n")
                else:
                    outFP.write(line)
                continue
            else:
                lineCols=line.split("\t")
                if lineCols[2]=="transcript":
                    chsID=lineCols[8].split("ID=")[-1].split(";")[0].strip()
                    if chsID in setStarts:
                        # now we shall collect all the necessary parts (exons) for the given novel transcript
                        if lineCols[6]=="+":
                            # change right-most coordinate of the transcript
                            transStart=lineCols[3]
                            lineCols[3]=str(int(transStart)-startDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"+ wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setStarts and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[3]==transStart:
                                        lineCols[3]=str(int(lineCols[3])-startDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                        else:
                            # change left-most coordinate of the transcript
                            transEnd=lineCols[4]
                            lineCols[4]=str(int(transEnd)+startDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setStarts and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[4]==transEnd:
                                        lineCols[4]=str(int(lineCols[4])+startDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                                        
                    elif chsID in setEnds:
                        # now we shall collect all the necessary parts (exons) for the given novel transcript
                        if lineCols[6]=="+":
                            # change right-most coordinate of the transcript
                            transEnd=lineCols[4]
                            lineCols[4]=str(int(transEnd)+endDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"+ wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setEnds and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[4]==transEnd:
                                        lineCols[4]=str(int(lineCols[4])-endDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                        else:
                            # change left-most coordinate of the transcript
                            transStart=lineCols[3]
                            lineCols[3]=str(int(transStart)+endDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setEnds and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[3]==transStart:
                                        lineCols[3]=str(int(lineCols[3])+endDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                    else:
                        outFP.write(line)
                else:
                    outFP.write(line)
        except StopIteration:
            break
            
outFP.close()

# %%
# now to do the same with the chess2.02_and_refseq.gff version

outFP=open("./chess2.04_and_refseq.gff","w+")
tmpLine=None
with open("./chess2.03_and_refseq.gff","r") as fp:
    ifp=iter(fp)
    while True:
        try:
            line=""
            if tmpLine==None:
                line=next(ifp)
            else:
                line=tmpLine
                tmpLine=None
                
            if line[0]=="#":
                if line[:7]=="##CHESS":
                    outFP.write("##CHESS"+version+"\n")
                else:
                    outFP.write(line)
                continue
            else:
                lineCols=line.split("\t")
                if lineCols[2]=="transcript":
                    chsID=lineCols[8].split("ID=")[-1].split(";")[0].strip()
                    if chsID in setStarts:
                        # now we shall collect all the necessary parts (exons) for the given novel transcript
                        if lineCols[6]=="+":
                            # change right-most coordinate of the transcript
                            transStart=lineCols[3]
                            lineCols[3]=str(int(transStart)-startDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"+ wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setStarts and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[3]==transStart:
                                        lineCols[3]=str(int(lineCols[3])-startDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                        else:
                            # change left-most coordinate of the transcript
                            transEnd=lineCols[4]
                            lineCols[4]=str(int(transEnd)+startDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setStarts and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[4]==transEnd:
                                        lineCols[4]=str(int(lineCols[4])+startDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                                        
                    elif chsID in setEnds:
                        # now we shall collect all the necessary parts (exons) for the given novel transcript
                        if lineCols[6]=="+":
                            # change right-most coordinate of the transcript
                            transEnd=lineCols[4]
                            lineCols[4]=str(int(transEnd)+endDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"+ wrong element, something is wrong with the gff format "+chsID+" "+transEnd
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setEnds and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[4]==transEnd:
                                        lineCols[4]=str(int(lineCols[4])-endDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                        else:
                            # change left-most coordinate of the transcript
                            transStart=lineCols[3]
                            lineCols[3]=str(int(transStart)+endDict[chsID])
                            outFP.write("\t".join(lineCols))
                            foundExon=False
                            while True:
                                line=next(ifp)
                                if line[0]=="#":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                lineCols=line.split("\t")
                                if not lineCols[2]=="exon":
                                    tmpLine=line
                                    assert foundExon==True,"- wrong element, something is wrong with the gff format "+chsID+" "+transStart
                                    break
                                else:
                                    parentID=lineCols[8].split("Parent=")[-1].split(";")[-1].strip()
                                    assert parentID in setEnds and parentID==chsID, "wrong exon identified "+parentID+" "+chsID
                                    if lineCols[3]==transStart:
                                        lineCols[3]=str(int(lineCols[3])+endDict[chsID])
                                        foundExon=True
                                        outFP.write("\t".join(lineCols))
                                    else:
                                        outFP.write(line)
                    else:
                        outFP.write(line)
                else:
                    outFP.write(line)
        except StopIteration:
            break
            
outFP.close()

# %%
# mapfile stays the same here
copyfile("./mapfile2.03.txt","mapfile2.04.txt")
# genes file should be just fine, although it would be best to verify that everything is indeed correct
ann=pd.read_csv("./chess2.04.gff",sep="\t",names=gff3Cols)
ann.dropna(inplace=True,axis=0)
ann=ann[ann["type"]=="gene"].reset_index(drop=True)
ann.head()
# the real problem here is the transcripts file, since we need to provide updated coordinates for it.
# Out:
#   seqid  source  type    start      end score strand phase  \
# 0  chr1  RefSeq  gene  11874.0  14409.0     .      +     .
# 1  chr1  RefSeq  gene  14362.0  29370.0     .      -     .
# 2  chr1  RefSeq  gene  29926.0  31295.0     .      +     .
# 3  chr1  RefSeq  gene  34611.0  36081.0     .      -     .
# 4  chr1  RefSeq  gene  51943.0  53959.0     .      +     .
#
#                                           attributes
# 0  ID=CHS.1;GENE_TYPE=misc_RNA;STATUS=known_refse...
# 1  ID=CHS.2;GENE_TYPE=misc_RNA;STATUS=known_refse...
# 2  ID=CHS.3;GENE_TYPE=lncRNA;STATUS=known_refseq;...
# 3  ID=CHS.4;GENE_TYPE=lncRNA;STATUS=known_refseq;...
# 4  ID=CHS.5;GENE_TYPE=lncRNA;STATUS=known_refseq;...

# %%
ann["id"]=ann.attributes.str.split("ID=",expand=True)[1].str.split(";",expand=True)[0]
ann.head()
ann["start"]==ann['start'].astype(int)
ann["end"]==ann['end'].astype(int)
ann.head()
# Out:
#   seqid  source  type    start      end score strand phase  \
# 0  chr1  RefSeq  gene  11874.0  14409.0     .      +     .
# 1  chr1  RefSeq  gene  14362.0  29370.0     .      -     .
# 2  chr1  RefSeq  gene  29926.0  31295.0     .      +     .
# 3  chr1  RefSeq  gene  34611.0  36081.0     .      -     .
# 4  chr1  RefSeq  gene  51943.0  53959.0     .      +     .
#
#                                           attributes     id
# 0  ID=CHS.1;GENE_TYPE=misc_RNA;STATUS=known_refse...  CHS.1
# 1  ID=CHS.2;GENE_TYPE=misc_RNA;STATUS=known_refse...  CHS.2
# 2  ID=CHS.3;GENE_TYPE=lncRNA;STATUS=known_refseq;...  CHS.3
# 3  ID=CHS.4;GENE_TYPE=lncRNA;STATUS=known_refseq;...  CHS.4
# 4  ID=CHS.5;GENE_TYPE=lncRNA;STATUS=known_refseq;...  CHS.5

# %%
genes=pd.read_csv("./chess2.03.genes",sep="\t")
genes.head()
# Out:
#         Gene_Type     Gene_Name     GFF_ID                    Location  \
# 0  protein_coding  LOC105371921  CHS.23496   chr17:80885776-80892131:-
# 1          lncRNA  LOC107986127  CHS.38280  chr3:127744219-127751505:-
# 2  protein_coding         RPS11  CHS.27254   chr19:49496365-49499712:+
# 3  protein_coding       CREB3L1   CHS.8579   chr11:46276634-46321430:+
# 4          lncRNA  LOC101930053  CHS.54970      chr9:2385141-2494223:-
#
#   Database RefSeq_GeneID                                       Description
# 0   RefSeq     105371921                      uncharacterized LOC105371921
# 1   RefSeq     107986127                      uncharacterized LOC107986127
# 2   RefSeq          6205                             ribosomal protein S11
# 3   RefSeq         90993  cAMP responsive element binding protein 3-like 1
# 4   RefSeq     101930053                      uncharacterized LOC101930053

# %%
# credit goes to https://stackoverflow.com/questions/12680754/split-explode-pandas-dataframe-string-entry-to-separate-rows/40449726#40449726
def explode(df, lst_cols, fill_value=''):
    # make sure `lst_cols` is a list
    if lst_cols and not isinstance(lst_cols, list):
        lst_cols = [lst_cols]
    # all columns except `lst_cols`
    idx_cols = df.columns.difference(lst_cols)

    # calculate lengths of lists
    lens = df[lst_cols[0]].str.len()

    if (lens > 0).all():
        # ALL lists in cells aren't empty
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .loc[:, df.columns]
    else:
        # at least one list in cells is empty
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .append(df.loc[lens==0, idx_cols]).fillna(fill_value) \
          .loc[:, df.columns]
    
genes=explode(genes.assign(GFF_ID=genes.GFF_ID.str.split(',')), 'GFF_ID')

# %%
mdf=genes.merge(ann[['id','start','end']],how="outer",left_on='GFF_ID',right_on='id',indicator=True)
mdf.head()
# Out:
#         Gene_Type     Gene_Name     GFF_ID                    Location  \
# 0  protein_coding  LOC105371921  CHS.23496   chr17:80885776-80892131:-
# 1          lncRNA  LOC107986127  CHS.38280  chr3:127744219-127751505:-
# 2  protein_coding         RPS11  CHS.27254   chr19:49496365-49499712:+
# 3  protein_coding       CREB3L1   CHS.8579   chr11:46276634-46321430:+
# 4          lncRNA  LOC101930053  CHS.54970      chr9:2385141-2494223:-
#
#   Database RefSeq_GeneID                                       Description  \
# 0   RefSeq     105371921                      uncharacterized LOC105371921
# 1   RefSeq     107986127                      uncharacterized LOC107986127
# 2   RefSeq          6205                             ribosomal protein S11
# 3   RefSeq         90993  cAMP responsive element binding protein 3-like 1
# 4   RefSeq     101930053                      uncharacterized LOC101930053
#
#           id        start          end _merge
# 0  CHS.23496   80885776.0   80892131.0   both
# 1  CHS.38280  127744219.0  127751505.0   both
# 2  CHS.27254   49496365.0   49499712.0   both
# 3   CHS.8579   46276634.0   46321430.0   both
# 4  CHS.54970    2385141.0    2494223.0   both

# %%
assert len(mdf[mdf["_merge"]=="left_only"])==0, "there are genes present in the .genes file but not in the annotation: "+";".join(mdf[mdf["_merge"]=="left_only"]["id"])
assert len(mdf[mdf["_merge"]=="right_only"])==0, " there are genes present in the annotation but not in the .genes file: "+";".join(mdf[mdf["_merge"]=="right_only"]["id"])

# %%
# genes file should be identical to the old one, since transcript coordinates should have never extended the old genes
# so let's verify this assumption is also correct
mdf['start']=mdf['start'].astype(int)
mdf['end']=mdf['end'].astype(int)
mdf[['start_old','end_old']]=mdf['Location'].str.split(':',expand=True)[1].str.split("-",expand=True)
mdf['start_old']=mdf['start_old'].astype(int)
mdf['end_old']=mdf['end_old'].astype(int)
display(mdf[~((mdf['start']==mdf['start_old'])&(mdf['end']==mdf['end_old']))])
assert len(mdf[(mdf['start']==mdf['start_old'])&(mdf['end']==mdf['end_old'])])==len(mdf),"something's wrong with the gene start and end coordinates"
# Out:
#             Gene_Type                Gene_Name     GFF_ID  \
# 48     protein_coding                   ZBTB12  CHS.48511
# 49     protein_coding                   ZBTB12  CHS.48732
# 50     protein_coding                   ZBTB12  CHS.49124
# 51     protein_coding                   ZBTB12  CHS.49345
# 75             lncRNA             LOC105375115  CHS.52474
# 76             lncRNA             LOC105375115  CHS.52499
# 85     protein_coding                 SERPINF1  CHS.23883
# 166    protein_coding                      ABR  CHS.23887
# 167    protein_coding                      ABR  CHS.23947
# 169    protein_coding                    OR9G1  CHS.10525
# 175            lncRNA             LOC107984555  CHS.14862
# 280          misc_RNA                    HLA-J  CHS.48258
# 281          misc_RNA                    HLA-J  CHS.48395
# 282          misc_RNA                    HLA-J  CHS.48620
# 283          misc_RNA                    HLA-J  CHS.48837
# 284          misc_RNA                    HLA-J  CHS.49023
# 285          misc_RNA                    HLA-J  CHS.49230
# 286          misc_RNA                    HLA-J  CHS.49451
# 333            lncRNA             LOC105378597  CHS.28495
# 342    protein_coding                   LILRA6  CHS.27857
# 343    protein_coding                   LILRA6  CHS.28035
# 344    protein_coding                   LILRA6  CHS.28085
# 345    protein_coding                   LILRA6  CHS.28395
# 403            lncRNA             LOC107984593  CHS.59635
# 418    protein_coding                   DNAJC9   CHS.6491
# 440    protein_coding                  TBC1D3B  CHS.23799
# 441    protein_coding                  TBC1D3B  CHS.23933
# 477            lncRNA                LOC574538  CHS.13397
# 481            lncRNA                 FLJ13224  CHS.13427
# 510    protein_coding                    OR8K3  CHS.10520
# ...               ...                      ...        ...
# 46586  protein_coding                   PRRC2A  CHS.48475
# 46587  protein_coding                   PRRC2A  CHS.48697
# 46588  protein_coding                   PRRC2A  CHS.48910
# 46589  protein_coding                   PRRC2A  CHS.49092
# 46590  protein_coding                   PRRC2A  CHS.49312
# 46591  protein_coding                   PRRC2A  CHS.49520
# 46614  protein_coding                   ZNF100  CHS.27835
# 46629          lncRNA             LOC105375795  CHS.54880
# 46632        misc_RNA                    HLA-L  CHS.48407
# 46633        misc_RNA                    HLA-L  CHS.48632
# 46634        misc_RNA                    HLA-L  CHS.48849
# 46635        misc_RNA                    HLA-L  CHS.49242
# 46636        misc_RNA                    HLA-L  CHS.49465
# 46638  protein_coding                    ATAT1  CHS.48420
# 46639  protein_coding                    ATAT1  CHS.48645
# 46640  protein_coding                    ATAT1  CHS.48862
# 46641  protein_coding                    ATAT1  CHS.49044
# 46642  protein_coding                    ATAT1  CHS.49255
# 46643  protein_coding                    ATAT1  CHS.49478
# 46678          lncRNA  LOC101929494,AC124789.1  CHS.23852
# 46684          lncRNA                  MIF-AS1  CHS.36357
# 46728  protein_coding                  TBC1D3J  CHS.23809
# 46755  protein_coding                   LILRA3  CHS.27902
# 46756  protein_coding                   LILRA3  CHS.28088
# 46757  protein_coding                   LILRA3  CHS.28399
# 46847          lncRNA                LOC150935  CHS.59478
# 46861  protein_coding                    SALL3  CHS.25089
# 46862  protein_coding                    SALL3  CHS.25098
# 46865  protein_coding                  GATAD2B  CHS.28440
# 46884          lncRNA             LOC107986668  CHS.49643
#
#                                                 Location        Database  \
# 48     chr6:31899194-31902331:-,chr6_GL000251v2_alt:3...          RefSeq
# 49     chr6:31899194-31902331:-,chr6_GL000251v2_alt:3...          RefSeq
# 50     chr6:31899194-31902331:-,chr6_GL000251v2_alt:3...          RefSeq
# 51     chr6:31899194-31902331:-,chr6_GL000251v2_alt:3...          RefSeq
# 75     chr7:174920-176013:+,chr7_KI270804v1_alt:13432...          RefSeq
# 76     chr7:174920-176013:+,chr7_KI270804v1_alt:13432...          RefSeq
# 85     chr17:1761965-1779392:+,chr17_KI270861v1_alt:1...          RefSeq
# 166    chr17:999953-1229713:-,chr17_KI270862v1_alt:42...          RefSeq
# 167    chr17:999953-1229713:-,chr17_KI270862v1_alt:42...          RefSeq
# 169    chr11:56700388-56701305:+,chr11_JH159137v1_alt...          RefSeq
# 175    chr13:112273139-112276195:+,chr13_KI270838v1_a...          RefSeq
# 280    chr6:30005971-30009956:+,chr6_GL000250v2_alt:1...          RefSeq
# 281    chr6:30005971-30009956:+,chr6_GL000250v2_alt:1...          RefSeq
# 282    chr6:30005971-30009956:+,chr6_GL000250v2_alt:1...          RefSeq
# 283    chr6:30005971-30009956:+,chr6_GL000250v2_alt:1...          RefSeq
# 284    chr6:30005971-30009956:+,chr6_GL000250v2_alt:1...          RefSeq
# 285    chr6:30005971-30009956:+,chr6_GL000250v2_alt:1...          RefSeq
# 286    chr6:30005971-30009956:+,chr6_GL000250v2_alt:1...          RefSeq
# 333    chr1:2633111-2641043:+,chr1_KI270762v1_alt:184...          RefSeq
# 342    chr19:54236592-54242768:-,chr19_GL949746v1_alt...          RefSeq
# 343    chr19:54236592-54242768:-,chr19_GL949746v1_alt...          RefSeq
# 344    chr19:54236592-54242768:-,chr19_GL949746v1_alt...          RefSeq
# 345    chr19:54236592-54242768:-,chr19_GL949746v1_alt...          RefSeq
# 403    chr13:114126120-114127591:+,KN538371.1:185211-...          RefSeq
# 418    chr10:73241954-73247331:-,chr10:73247342-73248...  RefSeq,GENCODE
# 440    chr17:36165681-36176624:-,chr17_KI270857v1_alt...          RefSeq
# 441    chr17:36165681-36176624:-,chr17_KI270857v1_alt...          RefSeq
# 477    chr12:137411-149169:-,chr12_GL877875v1_alt:131...          RefSeq
# 481    chr12:31324316-31325945:+,chr12_KI270835v1_alt...          RefSeq
# 510    chr11:56318307-56319245:+,chr11_JH159136v1_alt...          RefSeq
# ...                                                  ...             ...
# 46586  chr6:31618007-31637780:+,chr6_GL000251v2_alt:3...          RefSeq
# 46587  chr6:31618007-31637780:+,chr6_GL000251v2_alt:3...          RefSeq
# 46588  chr6:31618007-31637780:+,chr6_GL000251v2_alt:3...          RefSeq
# 46589  chr6:31618007-31637780:+,chr6_GL000251v2_alt:3...          RefSeq
# 46590  chr6:31618007-31637780:+,chr6_GL000251v2_alt:3...          RefSeq
# 46591  chr6:31618007-31637780:+,chr6_GL000251v2_alt:3...          RefSeq
# 46614  chr19:21722772-21767628:-,chr19_GL383575v2_alt...          RefSeq
# 46629  chr8:143043083-143045256:-,chr8_KI270817v1_alt...          RefSeq
# 46632  chr6:30259562-30273921:+,chr6_GL000251v2_alt:1...          RefSeq
# 46633  chr6:30259562-30273921:+,chr6_GL000251v2_alt:1...          RefSeq
# 46634  chr6:30259562-30273921:+,chr6_GL000251v2_alt:1...          RefSeq
# 46635  chr6:30259562-30273921:+,chr6_GL000251v2_alt:1...          RefSeq
# 46636  chr6:30259562-30273921:+,chr6_GL000251v2_alt:1...          RefSeq
# 46638  chr6:30626842-30646823:+,chr6_GL000251v2_alt:2...          RefSeq
# 46639  chr6:30626842-30646823:+,chr6_GL000251v2_alt:2...          RefSeq
# 46640  chr6:30626842-30646823:+,chr6_GL000251v2_alt:2...          RefSeq
# 46641  chr6:30626842-30646823:+,chr6_GL000251v2_alt:2...          RefSeq
# 46642  chr6:30626842-30646823:+,chr6_GL000251v2_alt:2...          RefSeq
# 46643  chr6:30626842-30646823:+,chr6_GL000251v2_alt:2...          RefSeq
# 46678  chr17:38450626-38452413:-,chr17_KI270857v1_alt...          RefSeq
# 46684  chr22:23886114-23898930:-,chr22_KI270879v1_alt...          RefSeq
# 46728  chr17:36450649-36458000:-,chr17_KI270857v1_alt...          RefSeq
# 46755  chr19_GL949746v1_alt:270735-275150:-,chr19_GL9...          RefSeq
# 46756  chr19_GL949746v1_alt:270735-275150:-,chr19_GL9...          RefSeq
# 46757  chr19_GL949746v1_alt:270735-275150:-,chr19_GL9...          RefSeq
# 46847  chr2:239762860-239800664:+,KN538362.1:65957-10...  RefSeq,GENCODE
# 46861  chr18:78980275-79002965:+,chr18_GL383572v1_alt...          RefSeq
# 46862  chr18:78980275-79002965:+,chr18_GL383572v1_alt...          RefSeq
# 46865  chr1:153793687-153923360:-,chr1_GL383518v1_alt...          RefSeq
# 46884  chr6:166254686-166259194:-,chr6_KI270802v1_alt...          RefSeq
#
#       RefSeq_GeneID                                        Description  \
# 48           221527           zinc finger and BTB domain containing 12
# 49           221527           zinc finger and BTB domain containing 12
# 50           221527           zinc finger and BTB domain containing 12
# 51           221527           zinc finger and BTB domain containing 12
# 75        105375115                       uncharacterized LOC105375115
# 76        105375115                       uncharacterized LOC105375115
# 85             5176                           serpin family F member 1
# 166              29                                 active BCR-related
# 167              29                                 active BCR-related
# 169          390174   olfactory receptor family 9 subfamily G member 1
# 175       107984555                       uncharacterized LOC107984555
# 280            3137  major histocompatibility complex%2C class I%2C...
# 281            3137  major histocompatibility complex%2C class I%2C...
# 282            3137  major histocompatibility complex%2C class I%2C...
# 283            3137  major histocompatibility complex%2C class I%2C...
# 284            3137  major histocompatibility complex%2C class I%2C...
# 285            3137  major histocompatibility complex%2C class I%2C...
# 286            3137  major histocompatibility complex%2C class I%2C...
# 333       105378597                       uncharacterized LOC105378597
# 342           79168          leukocyte immunoglobulin like receptor A6
# 343           79168          leukocyte immunoglobulin like receptor A6
# 344           79168          leukocyte immunoglobulin like receptor A6
# 345           79168          leukocyte immunoglobulin like receptor A6
# 403       107984593                       uncharacterized LOC107984593
# 418           23234   DnaJ heat shock protein family (Hsp40) member C9
# 440          414059                       TBC1 domain family member 3B
# 441          414059                       TBC1 domain family member 3B
# 477          574538                          uncharacterized LOC574538
# 481           79857                           uncharacterized LOC79857
# 510          219473  olfactory receptor family 8 subfamily K member...
# ...             ...                                                ...
# 46586          7916                        proline rich coiled-coil 2A
# 46587          7916                        proline rich coiled-coil 2A
# 46588          7916                        proline rich coiled-coil 2A
# 46589          7916                        proline rich coiled-coil 2A
# 46590          7916                        proline rich coiled-coil 2A
# 46591          7916                        proline rich coiled-coil 2A
# 46614        163227                            zinc finger protein 100
# 46629     105375795                       uncharacterized LOC105375795
# 46632          3139  major histocompatibility complex%2C class I%2C...
# 46633          3139  major histocompatibility complex%2C class I%2C...
# 46634          3139  major histocompatibility complex%2C class I%2C...
# 46635          3139  major histocompatibility complex%2C class I%2C...
# 46636          3139  major histocompatibility complex%2C class I%2C...
# 46638         79969                  alpha tubulin acetyltransferase 1
# 46639         79969                  alpha tubulin acetyltransferase 1
# 46640         79969                  alpha tubulin acetyltransferase 1
# 46641         79969                  alpha tubulin acetyltransferase 1
# 46642         79969                  alpha tubulin acetyltransferase 1
# 46643         79969                  alpha tubulin acetyltransferase 1
# 46678     101929494                       uncharacterized LOC101929494
# 46684        284889                                MIF antisense RNA 1
# 46728     100510707                       TBC1 domain family member 3J
# 46755         11026          leukocyte immunoglobulin like receptor A3
# 46756         11026          leukocyte immunoglobulin like receptor A3
# 46757         11026          leukocyte immunoglobulin like receptor A3
# 46847        150935                          uncharacterized LOC150935
# 46861         27164                  spalt-like transcription factor 3
# 46862         27164                  spalt-like transcription factor 3
# 46865         57459              GATA zinc finger domain containing 2B
# 46884     107986668                       uncharacterized LOC107986668
#
#               id     start       end _merge  start_old    end_old
# 48     CHS.48511   3377042   3379417   both   31899194   31902331
# 49     CHS.48732   3147391   3149766   both   31899194   31902331
# 50     CHS.49124   3241692   3244452   both   31899194   31902331
# 51     CHS.49345   3155590   3157967   both   31899194   31902331
# 75     CHS.52474    134324    135417   both     174920     176013
# 76     CHS.52499    167241    168334   both     174920     176013
# 85     CHS.23883    190927    195947   both    1761965    1779392
# 166    CHS.23887     42765    231794   both     999953    1229713
# 167    CHS.23947     42765    153205   both     999953    1229713
# 169    CHS.10525      7154      8071   both   56700388   56701305
# 175    CHS.14862     90257     92661   both  112273139  112276195
# 280    CHS.48258   1263680   1267665   both   30005971   30009956
# 281    CHS.48395   1485356   1489341   both   30005971   30009956
# 282    CHS.48620   1261506   1265491   both   30005971   30009956
# 283    CHS.48837   1266702   1270687   both   30005971   30009956
# 284    CHS.49023   1350027   1354012   both   30005971   30009956
# 285    CHS.49230   1261068   1265040   both   30005971   30009956
# 286    CHS.49451   1303778   1307763   both   30005971   30009956
# 333    CHS.28495    184276    187405   both    2633111    2641043
# 342    CHS.27857    212163    217575   both   54236592   54242768
# 343    CHS.28035    211581    217730   both   54236592   54242768
# 344    CHS.28085    213801    217756   both   54236592   54242768
# 345    CHS.28395    201519    218008   both   54236592   54242768
# 403    CHS.59635    185211    186682   both  114126120  114127591
# 418     CHS.6491  73247342  73248268   both   73241954   73247331
# 440    CHS.23799    400589    411512   both   36165681   36176624
# 441    CHS.23933    119784    130727   both   36165681   36176624
# 477    CHS.13397    131426    143184   both     137411     149169
# 481    CHS.13427    215110    216739   both   31324316   31325945
# 510    CHS.10520    129056    129994   both   56318307   56319245
# ...          ...       ...       ...    ...        ...        ...
# 46586  CHS.48475   3097961   3115064   both   31618007   31637780
# 46587  CHS.48697   2868437   2885541   both   31618007   31637780
# 46588  CHS.48910   2925714   2942818   both   31618007   31637780
# 46589  CHS.49092   2962555   2979657   both   31618007   31637780
# 46590  CHS.49312   2876495   2893595   both   31618007   31637780
# 46591  CHS.49520   2919955   2937058   both   31618007   31637780
# 46614  CHS.27835     85231    128818   both   21722772   21767628
# 46629  CHS.54880     33371     35544   both  143043083  143045256
# 46632  CHS.48407   1739329   1746646   both   30259562   30273921
# 46633  CHS.48632   1515431   1522820   both   30259562   30273921
# 46634  CHS.48849   1569799   1577184   both   30259562   30273921
# 46635  CHS.49242   1514659   1522046   both   30259562   30273921
# 46636  CHS.49465   1558042   1565431   both   30259562   30273921
# 46638  CHS.48420   2106566   2126545   both   30626842   30646823
# 46639  CHS.48645   1882672   1902652   both   30626842   30646823
# 46640  CHS.48862   1937071   1957052   both   30626842   30646823
# 46641  CHS.49044   1970890   1990873   both   30626842   30646823
# 46642  CHS.49255   1881930   1901911   both   30626842   30646823
# 46643  CHS.49478   1927600   1947582   both   30626842   30646823
# 46678  CHS.23852   2485898   2488747   both   38450626   38452413
# 46684  CHS.36357    130072    135292   both   23886114   23898930
# 46728  CHS.23809    685553    692904   both   36450649   36458000
# 46755  CHS.27902    270616    275031   both     270735     275150
# 46756  CHS.28088    270991    275406   both     270735     275150
# 46757  CHS.28399    270964    275379   both     270735     275150
# 46847  CHS.59478     65957    103761   both  239762860  239800664
# 46861  CHS.25089     45390     67793   both   78980275   79002965
# 46862  CHS.25098     45390     64084   both   78980275   79002965
# 46865  CHS.28440    121426    145051   both  153793687  153923360
# 46884  CHS.49643     34107     38615   both  166254686  166259194
#
# [3790 rows x 13 columns]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-e9eb8716d42c> in <module>()
#       7 mdf['end_old']=mdf['end_old'].astype(int)
#       8 display(mdf[~((mdf['start']==mdf['start_old'])&(mdf['end']==mdf['end_old']))])
# ----> 9 assert len(mdf[(mdf['start']==mdf['start_old'])&(mdf['end']==mdf['end_old'])])==len(mdf),"something's wrong with the gene start and end coordinates"
#
# AssertionError: something's wrong with the gene start and end coordinates

# %%
outFP=open("./chess2.04.genes","w+")

genesEvaluated=[]
wrongCoords=[]
header=True
with open("./chess2.03.genes") as inFP:
    for line in inFP.readlines():
        if header: # skip header
            outFP.write(line)
            header=False
            continue
        lineCols=line.split("\t")
        gids=lineCols[2].split(",")
        locs=lineCols[3].split(",")
        assert len(gids)==len(locs),"something is wrong with the following locus: "+lineCols[2]+"\t"+lineCols[3]
        newLocs=[]
        for gl in zip(gids,locs):
            genesEvaluated.append(gl[0]) # append geneID for verification later
            location=gl[1].split(":")
            coords=[int(x) for x in location[1].split("-")]
            ann_row=ann[ann['id']==gl[0]].reset_index(drop=True)
            assert len(ann_row)==1,"multiple rows?"
            if not int(ann_row['start'])==coords[0] and int(ann_row['end'])==coords[1]:
                wrongCoords.append(gl[0])
                
            newLocs.append(ann_row['seqid'].iloc[0]+":"+str(int(ann_row['start'].iloc[0]))+"-"+str(int(ann_row['end'].iloc[0]))+":"+location[-1])
        lineCols[3]=",".join(newLocs)
        outFP.write('\t'.join(lineCols))
inFP.close()
outFP.close()

# %%
print(wrongCoords)
print(len(genesEvaluated))
len(ann[~(ann["id"].isin(genesEvaluated))])
# Out:
# ['CHS.4228']
# 46972
# 323817

# %%
# now we need to replace old transcript coordinates with updated ones
ann=pd.read_csv("./chess2.04.gff",sep="\t",names=gff3Cols)
ann.dropna(inplace=True,axis=0)
ann=ann[ann["type"]=="transcript"].reset_index(drop=True)
ann["id"]=ann.attributes.str.split("ID=",expand=True)[1].str.split(";",expand=True)[0]
ann["start"]==ann['start'].astype(int)
ann["end"]==ann['end'].astype(int)
ann.head()
# Out:
#   seqid      source        type    start      end score strand phase  \
# 0  chr1  BestRefSeq  transcript  11874.0  14409.0     .      +     .
# 1  chr1  BestRefSeq  transcript  14362.0  29370.0     .      -     .
# 2  chr1   StringTie  transcript  14410.0  29369.0     .      -     .
# 3  chr1   StringTie  transcript  14410.0  29369.0     .      -     .
# 4  chr1   StringTie  transcript  14410.0  29369.0     .      -     .
#
#                                           attributes       id
# 0  ID=CHS.1.1;Parent=CHS.1;gene_name=DDX11L1;Dbxr...  CHS.1.1
# 1  ID=CHS.2.1;Parent=CHS.2;gene_name=WASH7P;Dbxre...  CHS.2.1
# 2  ID=CHS.2.2;Parent=CHS.2;STATUS=novel;ASSEMBLED...  CHS.2.2
# 3  ID=CHS.2.3;Parent=CHS.2;STATUS=novel;ASSEMBLED...  CHS.2.3
# 4  ID=CHS.2.4;Parent=CHS.2;STATUS=novel;ASSEMBLED...  CHS.2.4

# %%
ann['coords']=ann["start"].astype(int).astype(str)+"-"+ann["end"].astype(int).astype(str)
annDict=pd.Series(ann.coords.values,index=ann.id).to_dict()

# %%
outFP=open("./chess2.04.transcripts","w+")

transcriptsEvaluated=[]
wrongCoords=[]
header=True
with open("./chess2.03.transcripts") as inFP:
    for line in inFP.readlines():
        if header: # skip header
            outFP.write(line)
            header=False
            continue
        lineCols=line.split("\t")
        tid=lineCols[0]
        location=lineCols[7].split(":")
        transcriptsEvaluated.append(tid) # append geneID for verification later
        coords=[int(x) for x in location[1].split("-")]
        annCoords=[int(x) for x in annDict[tid].split("-")]
        if not int(annCoords[0])==coords[0] and int(annCoords[1])==coords[1]:
            wrongCoords.append(tl[0])
        newLoc=location[0]+":"+str(annCoords[0])+"-"+str(annCoords[1])+":"+location[-1]
        lineCols[7]=newLoc
        outFP.write('\t'.join(lineCols))
inFP.close()
outFP.close()

# %%
print(wrongCoords)
print(len(transcriptsEvaluated))
print(len(ann[~(ann["id"].isin(transcriptsEvaluated))]))
# Out:
# ['CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.36462.6', 'CHS.3646 ...
# 323817
# 0
