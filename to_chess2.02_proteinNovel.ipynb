# %%
import pandas as pd
import numpy as np
import os
import sys
import subprocess
from shutil import copyfile

gff3Cols=["seqid","source","type","start","end","score","strand","phase","attributes"]
version="2.02"

# %%
# first load all the protein coding novel genes
df=pd.read_csv("./chess2.01.gff",sep="\t",skiprows=3,names=gff3Cols)
df=df[(df["source"]=="CHESS")&(df["type"]=="gene")].reset_index(drop=True)
df=df[df["attributes"].str.contains("GENE_TYPE=protein_coding")].reset_index(drop=True)
df
# Out:
#                     seqid source  type        start          end score strand  \
# 0                    chr1  CHESS  gene     352749.0     356597.0     .      -
# 1                    chr1  CHESS  gene     499860.0     523759.0     .      -
# 2                    chr1  CHESS  gene    2314906.0    2324302.0     .      +
# 3                    chr1  CHESS  gene    4019392.0    4055669.0     .      +
# 4                    chr1  CHESS  gene    4553352.0    4571350.0     .      -
# 5                    chr1  CHESS  gene    7985921.0    8000843.0     .      +
# 6                    chr1  CHESS  gene    8912005.0    8912711.0     .      -
# 7                    chr1  CHESS  gene   10382101.0   10397576.0     .      +
# 8                    chr1  CHESS  gene   10393446.0   10397981.0     .      -
# 9                    chr1  CHESS  gene   11063249.0   11066558.0     .      -
# 10                   chr1  CHESS  gene   11893729.0   11897490.0     .      +
# 11                   chr1  CHESS  gene   12512562.0   12523273.0     .      -
# 12                   chr1  CHESS  gene   16237272.0   16240004.0     .      +
# 13                   chr1  CHESS  gene   16499368.0   16502081.0     .      +
# 14                   chr1  CHESS  gene   16507911.0   16511384.0     .      -
# 15                   chr1  CHESS  gene   19260139.0   19264343.0     .      -
# 16                   chr1  CHESS  gene   21387062.0   21390872.0     .      +
# 17                   chr1  CHESS  gene   22534265.0   22539503.0     .      -
# 18                   chr1  CHESS  gene   22663121.0   22665749.0     .      +
# 19                   chr1  CHESS  gene   23424864.0   23428558.0     .      +
# 20                   chr1  CHESS  gene   23703934.0   23724136.0     .      +
# 21                   chr1  CHESS  gene   23935200.0   23939589.0     .      +
# 22                   chr1  CHESS  gene   23989925.0   23995618.0     .      -
# 23                   chr1  CHESS  gene   24704846.0   24726999.0     .      +
# 24                   chr1  CHESS  gene   24873917.0   24877678.0     .      +
# 25                   chr1  CHESS  gene   25200692.0   25201875.0     .      +
# 26                   chr1  CHESS  gene   25232605.0   25236138.0     .      -
# 27                   chr1  CHESS  gene   25593211.0   25614127.0     .      -
# 28                   chr1  CHESS  gene   26595665.0   26597518.0     .      +
# 29                   chr1  CHESS  gene   26817347.0   26819141.0     .      +
# ...                   ...    ...   ...          ...          ...   ...    ...
# 1148                 chrX  CHESS  gene   49102609.0   49109879.0     .      +
# 1149                 chrX  CHESS  gene   49884137.0   49894891.0     .      +
# 1150                 chrX  CHESS  gene   53502273.0   53505294.0     .      +
# 1151                 chrX  CHESS  gene   53930018.0   53936082.0     .      +
# 1152                 chrX  CHESS  gene   71338940.0   71351122.0     .      +
# 1153                 chrX  CHESS  gene   72177800.0   72179996.0     .      +
# 1154                 chrX  CHESS  gene   72177845.0   72179997.0     .      -
# 1155                 chrX  CHESS  gene   74411759.0   74413185.0     .      -
# 1156                 chrX  CHESS  gene   74556156.0   74573701.0     .      +
# 1157                 chrX  CHESS  gene   84863167.0   84876548.0     .      -
# 1158                 chrX  CHESS  gene  109734339.0  109739330.0     .      -
# 1159                 chrX  CHESS  gene  118449967.0  118457488.0     .      -
# 1160                 chrX  CHESS  gene  119876905.0  119884344.0     .      +
# 1161                 chrX  CHESS  gene  119878397.0  119892434.0     .      +
# 1162                 chrX  CHESS  gene  123733151.0  123736047.0     .      +
# 1163                 chrX  CHESS  gene  134523860.0  134535411.0     .      -
# 1164                 chrX  CHESS  gene  134523909.0  134532418.0     .      +
# 1165                 chrX  CHESS  gene  134957544.0  134961405.0     .      +
# 1166                 chrX  CHESS  gene  149379210.0  149415521.0     .      -
# 1167                 chrX  CHESS  gene  150960527.0  150967838.0     .      -
# 1168                 chrX  CHESS  gene  154451762.0  154457939.0     .      +
# 1169  chrX_KI270880v1_alt  CHESS  gene       8945.0      12348.0     .      +
# 1170  chrX_KI270913v1_alt  CHESS  gene     101763.0     102651.0     .      +
# 1171                 chrY  CHESS  gene    3181376.0    3220764.0     .      -
# 1172                 chrY  CHESS  gene   11297415.0   11298241.0     .      -
# 1173                 chrY  CHESS  gene   22815955.0   22822521.0     .      -
# 1174                 chrY  CHESS  gene   56677927.0   56678468.0     .      +
# 1175                 chrY  CHESS  gene   56682661.0   56700981.0     .      +
# 1176                 chrY  CHESS  gene   56699417.0   56699988.0     .      +
# 1177                 chrY  CHESS  gene   56707793.0   56708089.0     .      +
#
#      phase                                         attributes
# 0        .  ID=CHS.12;description=potentially protein-codi...
# 1        .  ID=CHS.17;description=potentially protein-codi...
# 2        .  ID=CHS.144;description=potentially protein-cod...
# 3        .  ID=CHS.215;description=potentially protein-cod...
# 4        .  ID=CHS.219;description=potentially protein-cod...
# 5        .  ID=CHS.285;description=potentially protein-cod...
# 6        .  ID=CHS.305;description=potentially protein-cod...
# 7        .  ID=CHS.348;description=potentially protein-cod...
# 8        .  ID=CHS.353;description=potentially protein-cod...
# 9        .  ID=CHS.374;description=potentially protein-cod...
# 10       .  ID=CHS.411;description=potentially protein-cod...
# 11       .  ID=CHS.433;description=potentially protein-cod...
# 12       .  ID=CHS.545;description=potentially protein-cod...
# 13       .  ID=CHS.552;description=potentially protein-cod...
# 14       .  ID=CHS.553;description=potentially protein-cod...
# 15       .  ID=CHS.625;description=potentially protein-cod...
# 16       .  ID=CHS.696;description=potentially protein-cod...
# 17       .  ID=CHS.728;description=potentially protein-cod...
# 18       .  ID=CHS.733;description=potentially protein-cod...
# 19       .  ID=CHS.754;description=potentially protein-cod...
# 20       .  ID=CHS.772;description=potentially protein-cod...
# 21       .  ID=CHS.788;description=potentially protein-cod...
# 22       .  ID=CHS.793;description=potentially protein-cod...
# 23       .  ID=CHS.818;description=potentially protein-cod...
# 24       .  ID=CHS.824;description=potentially protein-cod...
# 25       .  ID=CHS.838;description=potentially protein-cod...
# 26       .  ID=CHS.841;description=potentially protein-cod...
# 27       .  ID=CHS.852;description=potentially protein-cod...
# 28       .  ID=CHS.903;description=potentially protein-cod...
# 29       .  ID=CHS.914;description=potentially protein-cod...
# ...    ...                                                ...
# 1148     .  ID=CHS.57993;description=potentially protein-c...
# 1149     .  ID=CHS.58024;description=potentially protein-c...
# 1150     .  ID=CHS.58080;description=potentially protein-c...
# 1151     .  ID=CHS.58086;description=potentially protein-c...
# 1152     .  ID=CHS.58238;description=potentially protein-c...
# 1153     .  ID=CHS.58258;description=potentially protein-c...
# 1154     .  ID=CHS.58259;description=potentially protein-c...
# 1155     .  ID=CHS.58293;description=potentially protein-c...
# 1156     .  ID=CHS.58296;description=potentially protein-c...
# 1157     .  ID=CHS.58357;description=potentially protein-c...
# 1158     .  ID=CHS.58555;description=potentially protein-c...
# 1159     .  ID=CHS.58623;description=potentially protein-c...
# 1160     .  ID=CHS.58665;description=potentially protein-c...
# 1161     .  ID=CHS.58666;description=potentially protein-c...
# 1162     .  ID=CHS.58721;description=potentially protein-c...
# 1163     .  ID=CHS.58816;description=potentially protein-c...
# 1164     .  ID=CHS.58817;description=potentially protein-c...
# 1165     .  ID=CHS.58829;description=potentially protein-c...
# 1166     .  ID=CHS.58949;description=potentially protein-c...
# 1167     .  ID=CHS.58977;description=potentially protein-c...
# 1168     .  ID=CHS.59084;description=potentially protein-c...
# 1169     .  ID=CHS.59135;description=potentially protein-c...
# 1170     .  ID=CHS.59143;description=potentially protein-c...
# 1171     .  ID=CHS.59184;description=potentially protein-c...
# 1172     .  ID=CHS.59253;description=potentially protein-c...
# 1173     .  ID=CHS.59337;description=potentially protein-c...
# 1174     .  ID=CHS.59372;description=potentially protein-c...
# 1175     .  ID=CHS.59373;description=potentially protein-c...
# 1176     .  ID=CHS.59375;description=potentially protein-c...
# 1177     .  ID=CHS.59378;description=potentially protein-c...
#
# [1178 rows x 9 columns]

# %%
# now need to extract gene IDs
df["id"]=df["attributes"].str.split("=",expand=True)[1].str.split(";",expand=True)[0]
df
# Out:
#                     seqid source  type        start          end score strand  \
# 0                    chr1  CHESS  gene     352749.0     356597.0     .      -
# 1                    chr1  CHESS  gene     499860.0     523759.0     .      -
# 2                    chr1  CHESS  gene    2314906.0    2324302.0     .      +
# 3                    chr1  CHESS  gene    4019392.0    4055669.0     .      +
# 4                    chr1  CHESS  gene    4553352.0    4571350.0     .      -
# 5                    chr1  CHESS  gene    7985921.0    8000843.0     .      +
# 6                    chr1  CHESS  gene    8912005.0    8912711.0     .      -
# 7                    chr1  CHESS  gene   10382101.0   10397576.0     .      +
# 8                    chr1  CHESS  gene   10393446.0   10397981.0     .      -
# 9                    chr1  CHESS  gene   11063249.0   11066558.0     .      -
# 10                   chr1  CHESS  gene   11893729.0   11897490.0     .      +
# 11                   chr1  CHESS  gene   12512562.0   12523273.0     .      -
# 12                   chr1  CHESS  gene   16237272.0   16240004.0     .      +
# 13                   chr1  CHESS  gene   16499368.0   16502081.0     .      +
# 14                   chr1  CHESS  gene   16507911.0   16511384.0     .      -
# 15                   chr1  CHESS  gene   19260139.0   19264343.0     .      -
# 16                   chr1  CHESS  gene   21387062.0   21390872.0     .      +
# 17                   chr1  CHESS  gene   22534265.0   22539503.0     .      -
# 18                   chr1  CHESS  gene   22663121.0   22665749.0     .      +
# 19                   chr1  CHESS  gene   23424864.0   23428558.0     .      +
# 20                   chr1  CHESS  gene   23703934.0   23724136.0     .      +
# 21                   chr1  CHESS  gene   23935200.0   23939589.0     .      +
# 22                   chr1  CHESS  gene   23989925.0   23995618.0     .      -
# 23                   chr1  CHESS  gene   24704846.0   24726999.0     .      +
# 24                   chr1  CHESS  gene   24873917.0   24877678.0     .      +
# 25                   chr1  CHESS  gene   25200692.0   25201875.0     .      +
# 26                   chr1  CHESS  gene   25232605.0   25236138.0     .      -
# 27                   chr1  CHESS  gene   25593211.0   25614127.0     .      -
# 28                   chr1  CHESS  gene   26595665.0   26597518.0     .      +
# 29                   chr1  CHESS  gene   26817347.0   26819141.0     .      +
# ...                   ...    ...   ...          ...          ...   ...    ...
# 1148                 chrX  CHESS  gene   49102609.0   49109879.0     .      +
# 1149                 chrX  CHESS  gene   49884137.0   49894891.0     .      +
# 1150                 chrX  CHESS  gene   53502273.0   53505294.0     .      +
# 1151                 chrX  CHESS  gene   53930018.0   53936082.0     .      +
# 1152                 chrX  CHESS  gene   71338940.0   71351122.0     .      +
# 1153                 chrX  CHESS  gene   72177800.0   72179996.0     .      +
# 1154                 chrX  CHESS  gene   72177845.0   72179997.0     .      -
# 1155                 chrX  CHESS  gene   74411759.0   74413185.0     .      -
# 1156                 chrX  CHESS  gene   74556156.0   74573701.0     .      +
# 1157                 chrX  CHESS  gene   84863167.0   84876548.0     .      -
# 1158                 chrX  CHESS  gene  109734339.0  109739330.0     .      -
# 1159                 chrX  CHESS  gene  118449967.0  118457488.0     .      -
# 1160                 chrX  CHESS  gene  119876905.0  119884344.0     .      +
# 1161                 chrX  CHESS  gene  119878397.0  119892434.0     .      +
# 1162                 chrX  CHESS  gene  123733151.0  123736047.0     .      +
# 1163                 chrX  CHESS  gene  134523860.0  134535411.0     .      -
# 1164                 chrX  CHESS  gene  134523909.0  134532418.0     .      +
# 1165                 chrX  CHESS  gene  134957544.0  134961405.0     .      +
# 1166                 chrX  CHESS  gene  149379210.0  149415521.0     .      -
# 1167                 chrX  CHESS  gene  150960527.0  150967838.0     .      -
# 1168                 chrX  CHESS  gene  154451762.0  154457939.0     .      +
# 1169  chrX_KI270880v1_alt  CHESS  gene       8945.0      12348.0     .      +
# 1170  chrX_KI270913v1_alt  CHESS  gene     101763.0     102651.0     .      +
# 1171                 chrY  CHESS  gene    3181376.0    3220764.0     .      -
# 1172                 chrY  CHESS  gene   11297415.0   11298241.0     .      -
# 1173                 chrY  CHESS  gene   22815955.0   22822521.0     .      -
# 1174                 chrY  CHESS  gene   56677927.0   56678468.0     .      +
# 1175                 chrY  CHESS  gene   56682661.0   56700981.0     .      +
# 1176                 chrY  CHESS  gene   56699417.0   56699988.0     .      +
# 1177                 chrY  CHESS  gene   56707793.0   56708089.0     .      +
#
#      phase                                         attributes         id
# 0        .  ID=CHS.12;description=potentially protein-codi...     CHS.12
# 1        .  ID=CHS.17;description=potentially protein-codi...     CHS.17
# 2        .  ID=CHS.144;description=potentially protein-cod...    CHS.144
# 3        .  ID=CHS.215;description=potentially protein-cod...    CHS.215
# 4        .  ID=CHS.219;description=potentially protein-cod...    CHS.219
# 5        .  ID=CHS.285;description=potentially protein-cod...    CHS.285
# 6        .  ID=CHS.305;description=potentially protein-cod...    CHS.305
# 7        .  ID=CHS.348;description=potentially protein-cod...    CHS.348
# 8        .  ID=CHS.353;description=potentially protein-cod...    CHS.353
# 9        .  ID=CHS.374;description=potentially protein-cod...    CHS.374
# 10       .  ID=CHS.411;description=potentially protein-cod...    CHS.411
# 11       .  ID=CHS.433;description=potentially protein-cod...    CHS.433
# 12       .  ID=CHS.545;description=potentially protein-cod...    CHS.545
# 13       .  ID=CHS.552;description=potentially protein-cod...    CHS.552
# 14       .  ID=CHS.553;description=potentially protein-cod...    CHS.553
# 15       .  ID=CHS.625;description=potentially protein-cod...    CHS.625
# 16       .  ID=CHS.696;description=potentially protein-cod...    CHS.696
# 17       .  ID=CHS.728;description=potentially protein-cod...    CHS.728
# 18       .  ID=CHS.733;description=potentially protein-cod...    CHS.733
# 19       .  ID=CHS.754;description=potentially protein-cod...    CHS.754
# 20       .  ID=CHS.772;description=potentially protein-cod...    CHS.772
# 21       .  ID=CHS.788;description=potentially protein-cod...    CHS.788
# 22       .  ID=CHS.793;description=potentially protein-cod...    CHS.793
# 23       .  ID=CHS.818;description=potentially protein-cod...    CHS.818
# 24       .  ID=CHS.824;description=potentially protein-cod...    CHS.824
# 25       .  ID=CHS.838;description=potentially protein-cod...    CHS.838
# 26       .  ID=CHS.841;description=potentially protein-cod...    CHS.841
# 27       .  ID=CHS.852;description=potentially protein-cod...    CHS.852
# 28       .  ID=CHS.903;description=potentially protein-cod...    CHS.903
# 29       .  ID=CHS.914;description=potentially protein-cod...    CHS.914
# ...    ...                                                ...        ...
# 1148     .  ID=CHS.57993;description=potentially protein-c...  CHS.57993
# 1149     .  ID=CHS.58024;description=potentially protein-c...  CHS.58024
# 1150     .  ID=CHS.58080;description=potentially protein-c...  CHS.58080
# 1151     .  ID=CHS.58086;description=potentially protein-c...  CHS.58086
# 1152     .  ID=CHS.58238;description=potentially protein-c...  CHS.58238
# 1153     .  ID=CHS.58258;description=potentially protein-c...  CHS.58258
# 1154     .  ID=CHS.58259;description=potentially protein-c...  CHS.58259
# 1155     .  ID=CHS.58293;description=potentially protein-c...  CHS.58293
# 1156     .  ID=CHS.58296;description=potentially protein-c...  CHS.58296
# 1157     .  ID=CHS.58357;description=potentially protein-c...  CHS.58357
# 1158     .  ID=CHS.58555;description=potentially protein-c...  CHS.58555
# 1159     .  ID=CHS.58623;description=potentially protein-c...  CHS.58623
# 1160     .  ID=CHS.58665;description=potentially protein-c...  CHS.58665
# 1161     .  ID=CHS.58666;description=potentially protein-c...  CHS.58666
# 1162     .  ID=CHS.58721;description=potentially protein-c...  CHS.58721
# 1163     .  ID=CHS.58816;description=potentially protein-c...  CHS.58816
# 1164     .  ID=CHS.58817;description=potentially protein-c...  CHS.58817
# 1165     .  ID=CHS.58829;description=potentially protein-c...  CHS.58829
# 1166     .  ID=CHS.58949;description=potentially protein-c...  CHS.58949
# 1167     .  ID=CHS.58977;description=potentially protein-c...  CHS.58977
# 1168     .  ID=CHS.59084;description=potentially protein-c...  CHS.59084
# 1169     .  ID=CHS.59135;description=potentially protein-c...  CHS.59135
# 1170     .  ID=CHS.59143;description=potentially protein-c...  CHS.59143
# 1171     .  ID=CHS.59184;description=potentially protein-c...  CHS.59184
# 1172     .  ID=CHS.59253;description=potentially protein-c...  CHS.59253
# 1173     .  ID=CHS.59337;description=potentially protein-c...  CHS.59337
# 1174     .  ID=CHS.59372;description=potentially protein-c...  CHS.59372
# 1175     .  ID=CHS.59373;description=potentially protein-c...  CHS.59373
# 1176     .  ID=CHS.59375;description=potentially protein-c...  CHS.59375
# 1177     .  ID=CHS.59378;description=potentially protein-c...  CHS.59378
#
# [1178 rows x 10 columns]

# %%
# now let's extract all chess gene ids from the protein.fa file
pgIDs=[]
with open("./chess2.01.protein.fa","r") as inFP:
    for line in inFP.readlines():
        if line[0]==">":
            curID=line.split(" ")[-1].split("gene=")[-1].strip()
            if curID[:4]=="CHS.":
                pgIDs.append(curID)
inFP.close()
pgIDs=set(pgIDs)
print(len(pgIDs))
# Out:
# 1218

# %%
# now create a set of annotations IDS from the df to look at the difference
agIDs=set(df["id"].tolist())
print(len(agIDs))
# Out:
# 1178

# %%
# now find the difference - which IDs are suspicious in the proteins.fa file
CDStoRemove=pgIDs-agIDs
print(len(CDStoRemove))
CDStoRemove
# Out:
# 40
# {'CHS.12707',
#  'CHS.13721',
#  'CHS.16010',
#  'CHS.18851',
#  'CHS.1895',
#  'CHS.20737',
#  'CHS.20929',
#  'CHS.2243',
#  'CHS.22699',
#  'CHS.22717',
#  'CHS.23255',
#  'CHS.24070',
#  'CHS.24382',
#  'CHS.26653',
#  'CHS.30768',
#  'CHS.3226',
#  'CHS.33898',
#  'CHS.34886',
#  'CHS.35336',
#  'CHS.35998',
#  'CHS.36118',
#  'CHS.43611',
#  'CHS.46428',
#  'CHS.46971',
#  'CHS.50923',
#  'CHS.5165',
#  'CHS.51749',
#  'CHS.51922',
#  'CHS.53081',
#  'CHS.54486',
#  'CHS.56484',
#  'CHS.57117',
#  'CHS.57814',
#  'CHS.58651',
#  'CHS.58832',
#  'CHS.6212',
#  'CHS.7754',
#  'CHS.7960',
#  'CHS.9165',
#  'CHS.9549'}

# %%
# now need ot modify the annotations by removing CDS entries corresponding to these genes

# first the chess2.01.gff
outFP=open("./chess2.02_and_refseq.gff","w+")

sources_and_refseq=[]

count=0
with open("chess2.01_and_refseq.gff","r") as inFP:
    for line in inFP.readlines():
        if not line[0]=="#": # skip comments, otherwise proceed safely
            lineCols=line.split("\t")
            if lineCols[2]=="CDS":
                geneID=".".join(lineCols[8].split("Parent=")[-1].strip().split(".")[:-1])
                if geneID in CDStoRemove:
                    sources_and_refseq.append(lineCols[1])
                    continue
            outFP.write(line)
        else:
            if line[:7]=="##CHESS":
                outFP.write("##CHESS"+version+"\n")
            else:
                outFP.write(line)
            continue

inFP.close()
outFP.close()

# %%
# now need ot modify the annotations by removing CDS entries corresponding to these genes

# first the chess2.01.gff
outFP=open("./chess2.02_assembly.gff","w+")

sources_assembly=[]

count=0
with open("chess2.01_assembly.gff","r") as inFP:
    for line in inFP.readlines():
        if not line[0]=="#": # skip comments, otherwise proceed safely
            lineCols=line.split("\t")
            if lineCols[2]=="CDS":
                geneID=".".join(lineCols[8].split("Parent=")[-1].strip().split(".")[:-1])
                if geneID in CDStoRemove:
                    sources_assembly.append(lineCols[1])
                    continue
            outFP.write(line)
        else:
            if line[:7]=="##CHESS":
                outFP.write("##CHESS"+version+"\n")
            else:
                outFP.write(line)
            continue

inFP.close()
outFP.close()

# %%
# now need ot modify the annotations by removing CDS entries corresponding to these genes

# first the chess2.01.gff
outFP=open("./chess2.02.gff","w+")

sources=[]

count=0
with open("chess2.01.gff","r") as inFP:
    for line in inFP.readlines():
        if not line[0]=="#": # skip comments, otherwise proceed safely
            lineCols=line.split("\t")
            if lineCols[2]=="CDS":
                geneID=".".join(lineCols[8].split("Parent=")[-1].strip().split(".")[:-1])
                if geneID in CDStoRemove:
                    sources.append(lineCols[1])
                    continue
            outFP.write(line)
        else:
            if line[:7]=="##CHESS":
                outFP.write("##CHESS"+version+"\n")
            else:
                outFP.write(line)
            continue

inFP.close()
outFP.close()

# %%
copyfile("./mapfile2.01.txt","./mapfile2.02.txt")
copyfile("./chess2.01.genes","./chess2.02.genes")
copyfile("./chess2.01.transcripts","./chess2.02.transcripts")
# Out:
# './chess2.02.transcripts'

# %%
print(set(sources_and_refseq))
print(set(sources_assembly))
print(set(sources))
# Out:
# {'FANTOM', 'CHESS'}
# {'FANTOM', 'CHESS'}
# {'FANTOM', 'CHESS'}

# %%
# now to convert the gff file into a proteins.fa file
subprocess.call(["gffread","-y","./chess2.02.protein.fa","-g","/home/sparrow/genomicData/hg38/hg38_p8.fa","./chess2.02.gff"])
# Out:
# 0
